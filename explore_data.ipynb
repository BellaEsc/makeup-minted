# %%
import pandas as pd

# %%
df = pd.read_csv("sephora.csv")
df.head()
# Out:
#                                                  url      pid  \
# 0  https://www.sephora.com/ca/en/product/sunnyday...  P500046
# 1  https://www.sephora.com/ca/en/product/argan-br...  P446641
# 2  https://www.sephora.com/ca/en/product/mini-lip...  P437097
# 3  https://www.sephora.com/ca/en/product/dyson-ai...  P500738
# 4  https://www.sephora.com/ca/en/product/lawless-...  P454981
#
#                                    name            brand currency  \
# 0      SunnyDays Lightweight Foundation  Tower 28 Beauty      CAD
# 1     Argan Bright Skin Vitamin C Serum      Josie Maran      CAD
# 2         Lip + Cheek Cream Blush Stick      MILK MAKEUP      CAD
# 3  Dyson Airwrap™ multi-styler Complete            Dyson      CAD
# 4     Satin Luxe Classic Cream Lipstick          LAWLESS      CAD
#
#   selling_price  original_price  discount_percentage availability  \
# 0           NaN           38.00                  NaN      InStock
# ...

# %%
df['ingredients'][1]
# Out:
# ' -Stabilized Vitamin C: Absorbs to increase radiance and glow. <br>-Rice Bran, Marshmallow Root, and Licorice Root: Boost luminosity. <br>-100 Percent Pure Argan Oil: Infuses skin with vitamin E, antioxidants, and firming omega essential fatty acids.<br><br>Argania Spinosa (Argan) Kernel Oil, Coconut Alkanes, Oleyl Lactate, Octyldodecyl Pca, Tetrahexyldecyl Ascorbate, Glyceryl Oleate, Dimethyl Isosorbide, Isostearyl Lactate, Brassica Campestris (Rapeseed) Seed Oil, Glycyrrhiza Glabra (Licorice) Root Extract, Polyglyceryl-3 Diisostearate, Althaea Officinalis Root Extract, Oryza Sativa (Rice) Bran Extract, Pterocarpus Marsupium Bark Extract, Bisabolol, Phloretin, Coco-Caprylate/Caprate, Squalane, Olea Europaea (Olive) Fruit Oil, Dunaliella Salina Extract (Beta Carotene Source).<br><br>\n<b>Clean at Sephora products are formulated without the following banned or restricted ingredients (please see Clean at Sephora landing page for full list of specific restrictions and allowances by cat
# ...

# %%
df2 = pd.read_csv("COSING_Ingredients-Fragrance Inventory_v2.csv", skiprows=9)
df2
# Out:
#        COSING Ref No                                          INCI name  \
# 0              94753    DISODIUM TETRAMETHYLHEXADECENYLCYSTEINE FORM...
# 1              94896   (LIQUIDAMBAR STYRACIFLUA/TRIBULUS TERRESTRIS)...
# 2              95645          ACRYLATES/VA/VINYL NEODECANOATE COPOLYMER
# 3              96229                   ASTROCARYUM VULGARE SEED BUTTER
# 4              89177                          BARLEY SH-POLYPEPTIDE-17
# ...              ...                                                ...
# 28705          91114   ACRYLOYL DIMETHYL TAURATE/MELAMINE/PEG-6 METH...
# 28706          90707   BACILLUS/(ASPARAGUS COCHINCHINENSIS/LYCIUM CH...
# 28707          90452   LACTOBACILLUS/HYDROLYZED [HONEY/SUGAR CANE/(A...
# 28708          90014   LACTOBACILLUS/RHODOPSEUDOMONAS/SACCHAROMYCES/...
# 28709          96255                             ULVA AUSTRALIS EXTRACT
#
#       INN name Ph. Eur. Name                       CAS No EC No  \
# ...
